# %% [markdown]
# # PythonSneks

# %%
#!pip install matplotlib numpy

# %%
# -*- coding: utf-8 -*-
"""
This program draws a heart using MatPlotLib.

You don't have to worry about how it does it, just make sure that it runs.
If it's successful, a heart will appear in the lower right.
"""

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap, BoundaryNorm

import logging
import matplotlib.font_manager
logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# %%
cmap = ListedColormap(['r', 'b', 'g'])
norm = BoundaryNorm([-1, -0.5, 0.5, 1], cmap.N)

t = np.arange(0,2*np.pi, 0.1)
x = 16*np.sin(t)**3
y = 13*np.cos(t)-5*np.cos(2*t)-2*np.cos(3*t)-np.cos(4*t)

plt.xkcd()
plt.plot(x,y, c='r')
plt.show()

# %% [markdown]
# # 1-6: Console

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # 1-7: Values

# %%
print(7-int("6"))
# Out:
# 1

# %%
x = input("Enter a number for x: ")
print("You entered:", x)
print("x - 6 =", int(x) - 6)
# Out:
# You entered: 4
# x - 6 = -2

# %% [markdown]
# # 1-8: Types

# %%
print("I am a string")
# Out:
# I am a string

# %%
print(7)
# Out:
# 7

# %%
print(True)
# Out:
# True

# %%
print(44.09)
# Out:
# 44.09

# %%
print(None)
# Out:
# None

# %% [markdown]
# # 1-9: Arithmetic Operations

# %%
print((7**4)-21+15*29+(15%3)+(86/2))
# Out:
# 2858.0

# %% [markdown]
# # 1-10: Conditional Operations

# %%
print(not 5>7 or not 5==4)
# Out:
# True

# %%
print(5>=8 and 2<=0)
# Out:
# False

# %%
8!=9 or 3<3
# Out:
# True

# %% [markdown]
# # 1-11: Variables

# %%
Lime = "Hayyan"
print(Lime + " is a potato")
# Out:
# Hayyan is a potato

# %% [markdown]
# # 1-12: Tracing

# %%
number = 0
print(number)
number = number + 99
print(number)
number = number + 1
print(number)
# Out:
# 0
# 99
# 100

# %% [markdown]
# # 1-13: Statements and Expressions

# %%
print("nothing much")
# Out:
# nothing much

# %% [markdown]
# # 2-14: Error Messages

# %%
print(7+"ikak")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(7+"ikak")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # 2-15: Strings

# %%
hi = "hi"
bye = """salutations my dear friewnd allow me to say say soem gibberish: jdslsjaflksdajfl;kdsjfl;kdsajfl;ksdajflksjdf;lksdjflkdsjlk;sdjl;fksdjl;kfjeslfjsdlk;fjsdal;kfjlsdk;jflsdkjf;lksdjf;slaf"""

# %% [markdown]
# # 2-16 Strings Operations

# %%
print("wow" in "wowowowow")
# Out:
# True

# %%
book = "book"
print(book[0])
# Out:
# b

# %%
print(book[0:3])
# Out:
# boo

# %% [markdown]
# # 2-17: Calling Functions

# %%
print(book.upper())
# Out:
# BOOK

# %%
print(book,"bye")
# Out:
# book bye

# %% [markdown]
# # 2-18: Calling Functions 2

# %%
print(input())
# Out:
# tr

# %% [markdown]
# # Project Turtle Art

# %%
'''
Section 1) Documentation

This program generates a drawing of ___________________________________________
______________________________________________________________________________.

I have neither given nor received unauthorized assistance on this assignment.
Signed: _______________________________
'''

# Section 2) Set-up
# Import the turtle library
import turtle

# %%
# Setup the graphics window
turtle.setup(500, 500, None, None)
turtle.title("Turtle Window")
turtle.reset()

# %%
# Section 3) Drawing
# Your code goes here


# Section 4) Wrap-up
# Tell the Turtle to stop accepting commands
turtle.done()
turtle.bye()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # 3-19: Debugging Techniques

# %%
print("nothing much")
# Out:
# nothing much

# %% [markdown]
# # 3-20: Defining Functions

# %%
def add(n1, n2):
    return n1 + n2
    
a = int(input("Enter your first number: "))
b = int(input("Enter your second number: "))
print(add(a,b))
# Out:
# 88

# %% [markdown]
# # 3-21: Unit Tests

# %%
print("Unit Tests are tests to see if the function works properly")
# Out:
# Unit Tests are tests to see if the function works properly

# %% [markdown]
# # 3-22: Return and Print

# %%
print("print like speaking")
print("return like having a value")
# Out:
# print like speaking
# return like having a value

# %% [markdown]
# # 3-23: Scope

# %% [markdown]
# # 4-24: Documenting

# %%
#hamburger

# %%
"""
jam
"""
# Out:
# '\njam\n'

# %% [markdown]
# # 4-25: Function Development

# %% [markdown]
# # 4-26: Data Flow

# %%
def calculate_grade(raw, weight):
    grade = 10 * (weight+raw) ** .5
    return grade

def print_grade(grade):
    print("Your grade was:", grade)

raw = 45
weight = 5 
grade = calculate_grade(raw, weight)
print_grade(grade)
# Out:
# Your grade was: 70.71067811865476

# %% [markdown]
# # 5-27: If Statements

# %%
var = 999
if var == 999:
    print("the var is equal to 999")
elif var == 1000:
    print("the var is equal to 1000")
else:
    print("the var is not equal to 999 or 1000")
# Out:
# the var is equal to 999

# %% [markdown]
# # 5-28: Truthiness

# %%
print("Boolean values are either True or False")
# Out:
# Boolean values are either True or False

# %%
print("String values are either empty or not empty")
# Out:
# String values are either empty or not empty
